# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("../datasets/raw/Online Retail.xlsx")

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB
# None

# %%
print(df.isna().sum())
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 5268

# %%
# summary discription of numerical datas
df.describe().T
# Out:
#                 count                           mean                  min  \
# Quantity     541909.0                        9.55225             -80995.0
# InvoiceDate    541909  2011-07-04 13:34:57.156386048  2010-12-01 08:26:00
# UnitPrice    541909.0                       4.611114            -11062.06
# CustomerID   406829.0                    15287.69057              12346.0
#
#                              25%                  50%                  75%  \
# Quantity                     1.0                  3.0                 10.0
# InvoiceDate  2011-03-28 11:34:00  2011-07-19 17:17:00  2011-10-19 11:27:00
# UnitPrice                   1.25                 2.08                 4.13
# CustomerID               13953.0              15152.0              16791.0
#
#                              max          std
# Quantity                 80995.0   218.081158
# InvoiceDate  2011-12-09 12:50:00          NaN
# UnitPrice                38970.0    96.759853
# ...

# %% [markdown]
# Inferences:
# This data contains a 541909 rows and 8 columns
#
# Quantity :This column contains number of products that has purchased in each transaction.its datatype is int.25% of the customers has purchased 1 products per transaction, 50% of the customers have perchased 3 products per transactions and 75% have purchased 10 products per transaction.
#
# InvoiceDate: Its is a DateTime Columns contains date and time of each transaction.
#
# UnitPice: Its is a float Columns contains unit price of Each Product.Our Data Contains 25% of 1.25$ product,50% of 2.08 and 75% of 4.13.

# %%
# description of categorical data
df.describe(include='object').T
# Out:
#               count unique                                 top    freq
# InvoiceNo    541909  25900                              573585    1114
# StockCode    541909   4070                              85123A    2313
# Description  540455   4223  WHITE HANGING HEART T-LIGHT HOLDER    2369
# Country      541909     38                      United Kingdom  495478
